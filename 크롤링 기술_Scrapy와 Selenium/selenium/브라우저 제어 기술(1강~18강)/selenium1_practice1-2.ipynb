# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

chromedriver = 'C:/dev_python/Webdriver/chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://www.naver.com/')
assert 'NAVER' in driver.title

search = driver.find_element_by_id('query')

search.clear()
search.send_keys('인디테이블')
search.send_keys(Keys.RETURN)

time.sleep(3)

blog_title = driver.find_elements_by_tag_name('a')

for each in blog_title:
    print(each.text)

driver.quit()
# Out:
# NAVER
# 한글 입력기
# 자동완성 레이어
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 로그인
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 서비스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 통합
# VIEW
# 이미지
# 지식iN
# 동영상
# 쇼핑
# 뉴스
# 어학사전
# 지도
# 책
# 더보기
#
#
#
#
#
# 공유
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이미지수
# 9
# 인디테이블
# 4.42방문자 리뷰 627
# 블로그 리뷰 633
# 길찾기
# 거리뷰
# 공유
# 경기 성남시 분당구 동판교로177번길 25
# 상세주소 열기/닫기
# 지도보기
# 더보기
# 더보기
# 인디브루
# 길찾기
# 인디플라워
# 길찾기
#
#
# 이전
# 다음
# 전체
# 블로그
# 카페
# 기본뷰
# 타임라인뷰
# 멀티미디어뷰
# 전체
# 메뉴
# 카페글
#
#
# 문서 저장하기
#
#
#
# 꽃씨의 맛집 이야기♬
# 판교 맛집 / 인도 커리 인디테이블
#
# 동영상 바로재생
# 01:10
#
#
#
#
#
#
#
#
#
#
#
# 판교 맛집 / 인도 커리 인디테이블 어릴 때는 카레를 그리 좋아하지 않았다. 그냥 급식에서 먹는 카레만... 커리를 가끔 먹기는 하지만, 가끔 커리가 먹고 싶을때 가는 곳은 인디테이블 그분의 쉬는 어느날 커리 먹고...
# #판교맛집
# #인디테이블
# #꽃씨의맛집이야기
# 삼평동 맛집 / 인도커리 인디테이블(#삼평동맛집 #꽃씨의맛집이야기)
# 판교역 맛집 / 커리 인디테이블(#판교역맛집 #인디테이블)
# 문서 저장하기
#
#
#
# 가장 가까이 다가서서 본 추억
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

chromedriver = 'C:/dev_python/Webdriver/chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

driver.get('https://www.python.org/')

assert 'Python' in driver.title

search = driver.find_element_by_name('q')
search.send_keys('python')
search.send_keys(Keys.RETURN)

assert 'No results found' not in driver.page_source
time.sleep(3)

h3s = driver.find_elements_by_tag_name('h3')
for h3 in h3s:
    print(h3.text)

driver.quit()
# Out:
# Results
# Python Documentation by Version
# Download Python for Other Platforms
# Release – Python 2.5.3
# Python 2.5.4 Release
# Release – Python 2.5.4
# Python 2.5.3 Release
# Python 2.5 Release
# Python 2.5.2 Release
# Sunsetting Python 2
# Python 2.5.1 Release
# Release – Python 3.1.4
# Release – Python 2.5.0
# Release – Python 2.5.2
# Python 3.1.4 Release
# Python 3.1.3 Release
# Release – Python 2.5.1
# Python 3.2.1 Release
# Release – Python 2.7.9rc1
# Python 3.0 Release
# Python 3.2.5 Release

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

phantomjs = 'C:/dev_python/Phantomjs/phantomjs'
driver = webdriver.PhantomJS(phantomjs)

driver.get('https://www.python.org/')
assert 'Python' in driver.title

search = driver.find_element_by_id('id-search-field')
search.clear()
search.send_keys('python')
search.send_keys(Keys.RETURN)

assert 'Not results found' not in driver.page_source

h3s = driver.find_elements_by_tag_name('h3')

for h3 in h3s:
    print(h3.text)

driver.quit()
# Out:
# Results
# Python Documentation by Version
# Download Python for Other Platforms
# Release – Python 2.5.3
# Python 2.5.4 Release
# Release – Python 2.5.4
# Python 2.5.3 Release
# Python 2.5 Release
# Python 2.5.2 Release
# Sunsetting Python 2
# Python 2.5.1 Release
# Release – Python 3.1.4
# Release – Python 2.5.0
# Release – Python 2.5.2
# Python 3.1.4 Release
# Python 3.1.3 Release
# Release – Python 2.5.1
# Python 3.2.1 Release
# Release – Python 2.7.9rc1
# Python 3.0 Release
# Python 3.2.5 Release

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

chromedriver = 'C:/dev_python/Webdriver/chromedriver.exe'

headless_options = webdriver.ChromeOptions()
headless_options.add_argument('headless')
headless_options.add_argument('window-size=1920x1080')
headless_options.add_argument('disable-gpu')
headless_options.add_argument('lang=ko_KOR')

driver = webdriver.Chrome(chromedriver, options = headless_options)
driver.get('https://www.python.org/')

assert 'Python' in driver.title

search_field = driver.find_element_by_name('q')
search_field.clear()
search_field.send_keys('Python')
search_field.send_keys(Keys.RETURN)

assert 'Not results found' not in driver.page_source

h3s = driver.find_elements_by_css_selector('#content > div > section > form > ul > li > h3 > a')

for index,h3 in enumerate(h3s):
    print(str(index+1)+'.'+h3.text)
# Out:
# 1.Python Documentation by Version
# 2.Download Python for Other Platforms
# 3.Python 2.5.3
# 4.Python 2.5.4 Release
# 5.Python 2.5.4
# 6.Python 2.5.3 Release
# 7.Python 2.5 Release
# 8.Python 2.5.2 Release
# 9.Sunsetting Python 2
# 10.Python 2.5.1 Release
# 11.Python 3.1.4
# 12.Python 2.5.0
# 13.Python 2.5.2
# 14.Python 3.1.4 Release
# 15.Python 3.1.3 Release
# 16.Python 2.5.1
# 17.Python 3.2.1 Release
# 18.Python 2.7.9rc1
# 19.Python 3.0 Release
# 20.Python 3.2.5 Release
