# %%
import requests

service_key = 'wtcVD1QK29jhpXVdii2dpMBD4N5SHG5FcpZSxVZgWFTYh5ciKw07SAA9mEf4TmOsvZgtgupmnTcc1JKt%2Bwmxeg%3D%3D'
params = '&numOfRows=10&sidoName=서울'

open_api = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?ServiceKey='+ service_key + params
res = requests.get(open_api)

print(res.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <response>
#   <header>
#     <resultCode>00</resultCode>
#     <resultMsg>NORMAL_CODE</resultMsg>
#   </header>
#   <body>
#     <items>
#       <item>
#         <so2Grade>1</so2Grade>
#         <coFlag/>
#         <khaiValue>62</khaiValue>
#         <so2Value>0.004</so2Value>
#         <coValue>0.5</coValue>
#         <pm10Flag/>
#         <o3Grade>2</o3Grade>
#         <pm10Value>26</pm10Value>
#         <khaiGrade>2</khaiGrade>
#         <sidoName>서울</sidoName>
#         <no2Flag/>
#         <no2Grade>1</no2Grade>
#         <o3Flag/>
#         <so2Flag/>
#         <dataTime>2021-07-21 15:00</dataTime>
#         <coGrade>1</coGrade>
#         <no2Value>0.022</no2Value>
#         <stationName>중구</stationName>
#         <pm10Grade>1</pm10Grade>
#         <o3Value>0.044</o3Value>
#       </item>
#       <item>
#         <so2Grade>1</so2Grade>
#         <coFlag/>
#         <khaiValue>57</khaiValue>
#         <so2Value>0.003</so2Value>
# ...

# %%
#xml포맷을 이용한 데이터를 파싱하는 방법
import requests
from bs4 import BeautifulSoup

service_key = 'wtcVD1QK29jhpXVdii2dpMBD4N5SHG5FcpZSxVZgWFTYh5ciKw07SAA9mEf4TmOsvZgtgupmnTcc1JKt%2Bwmxeg%3D%3D'
params = '&numOfRows=10&sidoName=서울' #params는 parameter의 준말!
open_api = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?ServiceKey='+ service_key + params

res = requests.get(open_api)
soup = BeautifulSoup(res.content,'html.parser')

data = soup.find_all('item')
#select 함수대신 find_all 함수가 적합
for item in data:
    stationname = item.find('stationname')
    pm10grade = item.find('pm10grade')
    print(stationname.get_text(), pm10grade.get_text())
# Out:
# 중구 1
# 한강대로 2
# 종로구 1
# 청계천로 1
# 종로 1
# 용산구 1
# 광진구 1
# 성동구 1
# 강변북로 1
# 중랑구 1

# %%
import openpyxl

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.title = '대기중미세먼지(실시간)'
excel_sheet.append(['지역명','pm10지수'])

import requests
from bs4 import BeautifulSoup

service_key = 'wtcVD1QK29jhpXVdii2dpMBD4N5SHG5FcpZSxVZgWFTYh5ciKw07SAA9mEf4TmOsvZgtgupmnTcc1JKt%2Bwmxeg%3D%3D'
params = '&numOfRows=10&sidoName=서울' #params는 parameter의 준말!
open_api = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?ServiceKey='+ service_key + params

res = requests.get(open_api)
soup = BeautifulSoup(res.content,'html.parser')

data = soup.find_all('item')
#select 함수대신 find_all 함수가 적합
for item in data:
    stationname = item.find('stationname').get_text()
    pm10grade = item.find('pm10grade').get_text()
    excel_sheet.append([stationname, pm10grade])
    
excel_file.save("xml포맷_연습1.xlsx")
excel_file.close()
